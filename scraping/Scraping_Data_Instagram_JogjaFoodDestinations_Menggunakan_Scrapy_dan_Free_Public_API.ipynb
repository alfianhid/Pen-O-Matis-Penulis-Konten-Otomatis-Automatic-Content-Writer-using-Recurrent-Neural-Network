# %%
# Koneksi ke Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Install library Scrapy untuk scraping data
# !pip install scrapy
# Out:
# ...
#      |████████████████████████████████| 254 kB 4.1 MB/s
# ...
#      |████████████████████████████████| 54 kB 2.4 MB/s
# ...
#      |████████████████████████████████| 47 kB 4.5 MB/s
# ...
#      |████████████████████████████████| 251 kB 7.4 MB/s
# ...
#      |████████████████████████████████| 3.2 MB 8.0 MB/s
# ...
#      |████████████████████████████████| 3.2 MB 31.8 MB/s
# ...
#      |████████████████████████████████| 65 kB 3.9 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 50.0 MB/s
# ...
#      |████████████████████████████████| 74 kB 4.1 MB/s
# ...
#   Created wheel for protego: filename=Protego-0.1.16-py3-none-any.whl size=7783 sha256=7871fb64481a259dbbc0eeaeb6733a1764e7e9b259ed50809b6beff461d210c5
#   Stored in directory: /root/.cache/pip/wheels/ca/44/01/3592ccfbcfaee4ab297c4097e6e9dbe1c7697e3531a39877ab
# ...
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.5-py3-none-any.whl size=11515 sha256=77e6404161872cc9dd4dd18f09b47437b1102bd1b2b6f267e2174bfa45043302
# ...

# %%
# Mengaktifkan library Scrapy
import scrapy

# %%
# Mengatur working directory
# %cd "/content/drive/My Drive/Colab Notebooks/"
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
# Membuat project InstaScraper yang secara otomatis membuatkan konfigurasi web scraping
# !scrapy startproject instascraperz
# Out:
# New Scrapy project 'instascraperz', using template directory '/usr/local/lib/python3.7/dist-packages/scrapy/templates/project', created in:
#     /content/drive/My Drive/Colab Notebooks/instascraperz
#
# You can start your first spider with:
#     cd instascraperz
#     scrapy genspider example example.com

# %%
# Membuat web spider yang akan meng-crawl dan scrape data dari Instagram
# %cd "/content/drive/My Drive/Colab Notebooks/instascraperz"
# !scrapy genspider instagram instagram.com
# Out:
# /content/drive/My Drive/Colab Notebooks/instascraperz
# Created spider 'instagram' using template 'basic' in module:
#   instascraperz.spiders.instagram

# %%
# Menjalankan web spider
# !scrapy crawl instagram -o test-scrapingz.csv
# Out:
# 2021-07-27 08:23:45 [scrapy.utils.log] INFO: Scrapy 2.5.0 started (bot: instascraperz)
# 2021-07-27 08:23:45 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 21.2.0, Python 3.7.11 (default, Jul  3 2021, 18:01:19) - [GCC 7.5.0], pyOpenSSL 20.0.1 (OpenSSL 1.1.1k  25 Mar 2021), cryptography 3.4.7, Platform Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic
# 2021-07-27 08:23:45 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2021-07-27 08:23:45 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'instascraperz',
#  'CONCURRENT_REQUESTS_PER_DOMAIN': 5,
#  'NEWSPIDER_MODULE': 'instascraperz.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['instascraperz.spiders']}
# 2021-07-27 08:23:45 [scrapy.extensions.telnet] INFO: Telnet Password: 2da068a50e03d60b
# 2021-07-27 08:23:45 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
# ...
