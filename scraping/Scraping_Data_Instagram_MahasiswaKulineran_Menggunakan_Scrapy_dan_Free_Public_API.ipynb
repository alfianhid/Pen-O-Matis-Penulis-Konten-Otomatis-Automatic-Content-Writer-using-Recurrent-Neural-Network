# %%
# Koneksi ke Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Install library Scrapy untuk scraping data
# !pip install scrapy
# Out:
# ...
#      |████████████████████████████████| 256kB 4.2MB/s
# ...
#      |████████████████████████████████| 71kB 6.3MB/s
# ...
#      |████████████████████████████████| 3.2MB 18.2MB/s
# ...
#      |████████████████████████████████| 256kB 29.3MB/s
# ...
#      |████████████████████████████████| 61kB 7.4MB/s
# ...
#      |████████████████████████████████| 3.1MB 41.2MB/s
# ...
#      |████████████████████████████████| 3.2MB 36.4MB/s
# ...
#      |████████████████████████████████| 81kB 8.4MB/s
# ...
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.5-cp37-none-any.whl size=11517 sha256=9129d5295b7da133dbcd7bfce2968b820250ae1493bff27e197d39b4974554f4
#   Stored in directory: /root/.cache/pip/wheels/88/99/96/cfef6665f9cb1522ee6757ae5955feedf2fe25f1737f91fa7f
# ...
#   Created wheel for protego: filename=Protego-0.1.16-cp37-none-any.whl size=7783 sha256=3a20cc2620f2556e013b1f455096d80add4160a9e0638ab47b10167334830269
#   Stored in directory: /root/.cache/pip/wheels/51/01/d1/4a2286a976dccd025ba679acacfe37320540df0f2283ecab12
# ...

# %%
# Mengaktifkan library Scrapy
import scrapy

# %%
# Mengatur working directory
# %cd "/content/drive/My Drive/Colab Notebooks/"
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
# Membuat project InstaScraper yang secara otomatis membuatkan konfigurasi web scraping
# !scrapy startproject instascraper
# Out:
# New Scrapy project 'instascraper', using template directory '/usr/local/lib/python3.7/dist-packages/scrapy/templates/project', created in:
#     /content/drive/My Drive/Colab Notebooks/instascraper
#
# You can start your first spider with:
#     cd instascraper
#     scrapy genspider example example.com

# %%
# Membuat web spider yang akan meng-crawl dan scrape data dari Instagram
# %cd "/content/drive/My Drive/Colab Notebooks/instascraper/"
# !scrapy genspider instagram instagram.com
# Out:
# /content/drive/My Drive/Colab Notebooks/instascraper
# Created spider 'instagram' using template 'basic' in module:
#   instascraper.spiders.instagram

# %%
# Menjalankan web spider
# !scrapy crawl instagram -o test-scraping.csv
# Out:
# 2021-07-14 14:36:45 [scrapy.utils.log] INFO: Scrapy 2.5.0 started (bot: instascraper)
# 2021-07-14 14:36:45 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 21.2.0, Python 3.7.10 (default, May  3 2021, 02:48:31) - [GCC 7.5.0], pyOpenSSL 20.0.1 (OpenSSL 1.1.1k  25 Mar 2021), cryptography 3.4.7, Platform Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic
# 2021-07-14 14:36:45 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2021-07-14 14:36:45 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'instascraper',
#  'CONCURRENT_REQUESTS_PER_DOMAIN': 5,
#  'NEWSPIDER_MODULE': 'instascraper.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['instascraper.spiders']}
# 2021-07-14 14:36:45 [scrapy.extensions.telnet] INFO: Telnet Password: b70ba4e424eefbc5
# 2021-07-14 14:36:45 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
# ...
